# %% [markdown]
# <a href="https://colab.research.google.com/github/Kadidjah/Algoritmos_Aperfeicoamento/blob/main/C%C3%B3pia_de_Algoritmo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calcular media

# %%
nota1=float(input)
nota2=float
nota3=float
media=float
media=(nota1+nota2+nota3)/2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_28719/2557635129.py in <cell line: 0>()
#       3 nota3=float
#       4 media=float
# ----> 5 media=(nota1+nota2+nota3)/2
#
# TypeError: unsupported operand type(s) for +: 'type' and 'type'
